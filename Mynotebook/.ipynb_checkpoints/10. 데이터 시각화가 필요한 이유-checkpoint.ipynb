# %% [markdown]
# # 직접 해보세요!
# ## 앤스콤 데이터 집합 불러온 후 그래프 그리기(77쪽)

# %% [markdown]
# - 데이터 시각화를 보여주는 전형적인 사례로 엔스콤 4분할 그래프(Anscombe's quarter)가 있다.
# - 이 그래프는 영국의 프랭크 앤스콤(Frank Anscombe)이 데이터를 시각화하지 않고 수치만 확인할 때 발생할 수 있는 함정을 보여주기 위해 만든 그래프다.

# %% [markdown]
# - 엔스콤 4분할 그래프를 구성하는 데이터 집합은 4개의 그룹으로 구성되어 있으며 모든 데이터 그룹은 x, y 열을 가지고 있다.
# - 그런데 이 4개의 데이터 그룹은 각각 평균, 분산과 같은 수칫값이나 상관관계, 회귀선이 같다는 특징이 있다.
# - 그래서 이 결과만 보고 '데이터 그룹 1,2,3,4의 데이터는 모두 같을 것이다'라고 착각할 수 있다. 바로 이것이 엔스콤이 지적한 '함정'이다.
# - 하지만 각 데이터 그룹을 시각화하면 데이터 그룹이 서로 다른 데이터 패턴을 가지고 있다는 점을 금방 알 수 있다.
# - 이런 점에서 데이터 시각화는 데이터 분석 분야에서 아주 중요한 요소라고 할 수 있다.

# %% [markdown]
# ### 1. 앤스콤 데이터 집합 불러오기

# %% [markdown]
# - 앤스콤 데이터 집합은 seaborn 라이브러리에 포함되어 있다. seaborn라이브러리의 load_dataset 메서드에 문자열 anscombe을 전달하면 엔스콤 데이터 집합을 불러올 수 있다.
# - 이때 데이터프레임의 열 이름 중 dataset열이 데이터 그룹을 구분한다는 것을 알 수 있다.

# %%
import seaborn as sns 
anscombe = sns.load_dataset("anscombe") 
print(anscombe.head(5))
print(type(anscombe))
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# - matplotlib 라이브러리로 그래프 그리기
# - 그래프를 그리기 위해  matplotlib 라이브러리를 사용한다.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
plt.plot(dataset_1['x'], dataset_1['y'])

# %% [markdown]
# - plot 메서드는 기본적으로 선으로 그래프를 그린다. 만약 점으로 그래프를 그리려면 o을 세 번째 인자로 전달하면 된다.

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# - 앤스콤 데이터 집합 모두 사용해 그래프 만들기
# - 앤스콤 데이터 집합은 4개의 데이터 그룹으로 구성되어 있으며 각 데이터 그룹의 차이를 파악하려면 그래프로 시각화해야 한다고 했다.

# %% [markdown]
# - matplotlib 라이브러리로 그래프 그리기
# - 이번에 소개할 내용은 'matplotlib 라이브러리로 그래프 그리는 방법'이다.
# - 아래에 정리한 과정을 잘 읽어보면 블록을 조립하는 과정과 비슷하다는 것을 알 수 있을 것이다.
#     - 전체 그래프가 위치할 기본 틀을 만든다.
#     - 그래프를 그려 넣을 그래프 격자를 만든다.
#     - 그런 다음 격자에 그래프를 하나씩 추가한다. 격자에 그래프가 추가되는 순서는 왼쪽에서 오른쪽 방향이다.
#     - 만약 격자의 첫 번째 행이 꽉 차면 두 번째 행에 그래프를 그려 넣는다.
# - 즉 이후 실습에서 앤스콤 데이터 집합으로 그리게 될 그래프의 격자 크기는 4이고 세 번째 그래프의 경우 2행 1열 위치에 그려진다.

# %% [markdown]
# - 앤스콤 데이터프레임의 dataset 열의 값이 I, II, III, IV인 것은 불린 추출하여 dataset 1,2,3,4에 저장한다.

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II'] 
dataset_3 = anscombe[anscombe['dataset'] == 'III'] 
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %% [markdown]
# - 먼저 그래프 격자가 위치할 기본 틀을 만든다.
# - 그런 다음 add_subplot 메서드로 그래프 격자를 그린다. 기본 틀(flg)에 격자를 추가한다는 기분으로 add_subplot메서드를 사용하면 된다.
# - add_subplot의 첫 번째 인자에는 그래프 기본 틀의 행 크기를, 두 번째 인자에는 그래프 기본 틀의 열 크기를 지정한다.

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %% [markdown]
# - 이제 plot 메서드에 데이터를 전달하여 그래프를 그리면 된다.
# - 이번에는 점으로 그래프를 표현했다. 그래프를 확인하려면 flg를 반드시 입력해야 한다.

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o') 
axes2.plot(dataset_2['x'], dataset_2['y'], 'o') 
axes3.plot(dataset_3['x'], dataset_3['y'], 'o') 
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %% [markdown]
# - 각각의 그래프를 쉽게 구분할 수 있도록 그래프 격자에 제목을 추가해 볼까요?
# - set_title메서드로 그래프 이름을 전달하면 그래프 격자에 제목이 추가된다.

# %%
axes1.set_title("dataset_1") 
axes2.set_title("dataset_2")
axes3.set_title("dataset_3") 
axes4.set_title("dataset_4")

fig

# %% [markdown]
# - 기본 틀(flg)에도 제목을 추가해보자. 기본 틀에 제목을 추가하려면 suptitle 메서드를 사용하며면 된다.

# %%
fig.suptitle("Anscombe Data")

fig

# %% [markdown]
# - 그런데 위의 과정에서 그래프를 보면 각 그래프의 이름과 숫자가 겹쳐보인다.
# - 이런 경우에는 tight_layout 메서드를 호출하여 각 그래프의 레이아웃을 조절할 수 있다.

# %%
fig.tight_layout()

fig
