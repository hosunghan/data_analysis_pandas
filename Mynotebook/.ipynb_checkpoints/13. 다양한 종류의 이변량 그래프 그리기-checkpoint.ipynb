# %% [markdown]
# # 직접 해보세요!
# ## 다양한 종류의 이변량 그래프 그리기(95쪽)

# %% [markdown]
# ### 1. seaborn 라이브러리로 산점도 그래프 그리기
# - seaborn 라이브러리로 산점도 그래프 그리기
# 	- seaborn 라이브러리는 matplotlib 라이브러리보다 다양한 방법으로 산점도 그래프를 그릴 수 있다.
# 	- 산점도 그래프를 그리려면 seaborn 라이브러리의 regplot 메서드를 사용해야 한다.
# 	- regplot 메서드를 사용하면 산점도 그래프와 회귀선을 함께 그릴 수 있다.
# 	- 만약 회귀선을 제거하려면 fit_reg 인자를 False로 지정하면 된다.

# %%
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# - 이번에는 산점도 그래프와 히스토그램을 한 번에 그려주는 jointplot 메서드를 사용해보자.
# - x, y 인자에 원하는 열 이름을 지정하고 data 인자 값으로 데이터프레임을 지정하면 그래프를 그릴 수 있다.

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips) 
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# - 산점도 그래프는 점이 겹쳐 보일 경우 점을 구분하기 어렵다는 단점이 있다.
# - 만약 산점도 그래프를 구분하기 쉽게 그리고 싶다면 육각 그래프(hexbin)를 사용하면 된다.
# - 육각 그래프는 2차원 표면에 육각형으로 데이터를 쌓아 표현하는 그래프이다.
# - 그래서 특정 데이터의 개수가 많아지면 점점 진한 색으로 표현횐다. 육각 그래프는 위에서 사용한 jointplot 메서드를 그대로 사용한다. 대신 kind 인자값을 Hex로 지정하면 된다.

# %%
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex") 
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# ### 4. 이차원 밀집도 그리기

# %% [markdown]
# - 이번에는 이차원 밀집도를 그려보자. 이차원 밀집도는 Kdeplot 메서드로 만들수 있다.
# - 다음은 tips 데이터를 전달하여 밀집도를 그린 것이다.

# %%
kde, ax = plt.subplots() 
ax = sns.kdeplot(data=tips['tip'],
                x=tips['tip'],
                 y=tips['total_bill'],
                 fill=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 5. 바 그래프 그리기

# %% [markdown]
# - 이번에는 바 그래프를 그려보자. 바 그래프는 지정한 변수의 평균을 계산하여 그릴 수 있다.
# - 다음은 시간에 따라 지불한 비용의 평균을 바 그래프로 나타낸 것이다.

# %%
ax = plt.subplots() 
ax = sns.barplot(x='time', y='total_bill', data=tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# ### 6. 박스 그래프 그리기

# %% [markdown]
# - 박스 그래프도 그려보겠다. 박스 그래프는 최소값, 1분위수, 중간값, 3분위수, 최대값, 이상치 등 다양한 통계량을 한 번에 표현하는 그래프다.

# %%
ax = plt.subplots() 
ax = sns.boxplot(x='time', y='total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# - 박스 그래프는 다양한 통계 수치를 확인하기 위해 자주 사용하는 그래프지만 데이터 분산이 모호하게 표현된다.
# - 이런 경우에는 박스 그래프에 커널 밀도를 추정한 바이올린 그래프를 사용하면 된다.
# - 쉽게 말해 위의 박스 형태를 바이올린 형태로 바꾸면 바이올린 그래프가 된다.
# - 바이올린 그래프는 violinplot 메서드를 사용하여 그릴 수 있다.

# %%
ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ### 8. 관계 그래프 그리기

# %% [markdown]
# - 관계 그래프는 지금까지 설명한 그래프를 종합한 그래프라고 생각하면 된다.
# - 관계 그래프는 pairplot 메서드에 데이터프레임을 넣는 방법으로 간단하게 그릴 수 있다.

# %%
fig = sns.pairplot(tips)

# %% [markdown]
# - 위의 관계 그래프는 중복된 정보가 표현된다. 즉, 관계 그래프의 절반(대각선 기준으로 위)은 나머지 절반(대각선 기준으로 아래)과 같다.
# - 이런 경우에는 중복된 그래프가 그려지는 위치를 직접 지정하여 원하는데로 교체하면 된다.

# %% [markdown]
# - map_upper 메서드는 대각선을 기준으로 위에 그릴 그래프를 지정한다.
# - 반대로 map_lower 메서드는 대각선을 기준으로 아래쪽에 그릴 그래프를 지정한다.
# - map_diag는 대각선을 중심으로 그래프를 그린다.
# - 다음은 이차원 밀집도를 대각선 기준으로 아래에, 산점도를 대각선 기준으로 위에, 히스토그램과 밀집도는 대각선을 중심으로 그린다.

# %%
pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.histplot) 
plt.show()
